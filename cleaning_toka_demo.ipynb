# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wuzzuf.csv')
df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %% [markdown]
# # **Check missing values**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8983 entries, 0 to 8982
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 8983 non-null   object
#  1   Working_Hours         8983 non-null   object
#  2   Working_Place         8983 non-null   object
#  3   Company               7949 non-null   object
#  4   Location              8983 non-null   object
#  5   Post_Date             8983 non-null   object
#  6   Number_of_Applicants  8982 non-null   object
#  7   Number_of_Positions   8668 non-null   object
#  8   Experience            8983 non-null   object
#  9   Career_Level          8983 non-null   object
#  10  Education             8983 non-null   object
#  11  Salary                8983 non-null   object
#  12  Job_Category          8983 non-null   object
#  13  Skills                8983 non-null   object
# dtypes: object(14)
# memory usage: 982.6+ KB

# %%
df["Salary"].unique()
# Out:
# array(['Confidential', '8000 To 12000 EGP Per Month', 'Male', ...,
#        '10000 To 15000 EGP Per Month, Transportations - Incentives',
#        'Confidential, Overtime Pay: Compensation For Hours Worked Beyond The Standard Working Hours, Typically Paid At A Higher Rate. PTO',
#        '10000 To 30000 EGP Per Month, Bonus Commission'], dtype=object)

# %%
print(df[df["Salary"] == "Female"])
# Out:
#                                    Title Working_Hours Working_Place  \
# 16    Administrative Assistant (Gharbia)     Full Time       On-site
# 38           Accountant - Female - Zaher     Full Time       On-site
# 86               CEO Executive Assistant     Full Time        Remote
# 207                  Executive Secretary     Full Time       On-site
# 238      Cad drafter/Cad Design Engineer     Full Time       On-site
# ...                                  ...           ...           ...
# 8777      Customer Advisor / Sales Admin     Full Time        Remote
# 8790                      Office Manager     Full Time       On-site
# 8856            Administrative Assistant     Full Time       On-site
# 8865         Chairman Personal Assistant     Full Time       On-site
# 8900    Admin Assistant - Office Manager     Full Time       On-site
#
#                                       Company                Location  \
# ...

# %%
print(df[df["Salary"] == "Male"])
# Out:
#                                        Title Working_Hours Working_Place  \
# 5                                 Accountant     Full Time       On-site
# 40           Electrical Maintenance Engineer   Shift Based       On-site
# 41        Sales & Technical Support Engineer     Full Time       On-site
# 67                      Maintenance Engineer     Full Time       On-site
# 77                          Project Director     Full Time       On-site
# ...                                      ...           ...           ...
# 8913         Production Maintenance Engineer     Full Time       On-site
# 8924               IT Infrastructure Manager     Full Time       On-site
# 8926              Mechanical Design Engineer     Full Time       On-site
# 8932                      General Supervisor     Full Time       On-site
# 8943  Electrical Automation Control Engineer     Full Time       On-site
#
#                                           Company               Location  \
# ...

# %%
# take a copy from salary column to get gender column
df['Gender'] = df['Salary']

df["Gender"] = df["Gender"].apply(lambda x: x if x in ["Female", "Male"] else np.nan)

df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %%
df["Salary"] = df["Salary"].apply(lambda x: np.nan if x in ["Female", "Male"] else x)
df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %%
print(df[df["Salary"] == "Male"])
# Out:
# Empty DataFrame
# Columns: [Title, Working_Hours, Working_Place, Company, Location, Post_Date, Number_of_Applicants, Number_of_Positions, Experience, Career_Level, Education, Salary, Job_Category, Skills, Gender]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8983 entries, 0 to 8982
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 8983 non-null   object
#  1   Working_Hours         8983 non-null   object
#  2   Working_Place         8983 non-null   object
#  3   Company               7949 non-null   object
#  4   Location              8983 non-null   object
#  5   Post_Date             8983 non-null   object
#  6   Number_of_Applicants  8982 non-null   object
#  7   Number_of_Positions   8668 non-null   object
#  8   Experience            8983 non-null   object
#  9   Career_Level          8983 non-null   object
#  10  Education             8983 non-null   object
#  11  Salary                8176 non-null   object
#  12  Job_Category          8983 non-null   object
#  13  Skills                8983 non-null   object
#  14  Gender                807 non-null    object
# ...

# %%
print(df.isnull().sum())
# Out:
# Title                      0
# Working_Hours              0
# Working_Place              0
# Company                 1034
# Location                   0
# Post_Date                  0
# Number_of_Applicants       1
# Number_of_Positions      315
# Experience                 0
# Career_Level               0
# Education                  0
# Salary                   807
# Job_Category               0
# Skills                     0
# Gender                  8176
# dtype: int64

# %%
columns_to_check = ['Company', 'Number_of_Positions', 'Salary']

# Find rows where all selected columns have missing values
missing_rows = df[df[columns_to_check].isnull().all(axis=1)]

missing_rows
# Out:
# Empty DataFrame
# Columns: [Title, Working_Hours, Working_Place, Company, Location, Post_Date, Number_of_Applicants, Number_of_Positions, Experience, Career_Level, Education, Salary, Job_Category, Skills, Gender]
# Index: []

# %% [markdown]
# not preferred to drop rows

# %%
df["Number_of_Positions"]
# Out:
# 0        1 open position
# 1        1 open position
# 2       2 open positions
# 3       4 open positions
# 4        1 open position
#               ...
# 8978                 NaN
# 8979                 NaN
# 8980     1 open position
# 8981     1 open position
# 8982    5 open positions
# Name: Number_of_Positions, Length: 8983, dtype: object

# %%
df["Number_of_Positions"] = df["Number_of_Positions"].str.extract(r'(\d+)')
df["Number_of_Positions"]
# Out:
# 0         1
# 1         1
# 2         2
# 3         4
# 4         1
#        ...
# 8978    NaN
# 8979    NaN
# 8980      1
# 8981      1
# 8982      5
# Name: Number_of_Positions, Length: 8983, dtype: object

# %%
full_time_count = len(df[df["Working_Hours"] == "Full Time"])
print(f"Number of rows with 'Working_Hours' equal to 'Full Time': {full_time_count}")
# Out:
# Number of rows with 'Working_Hours' equal to 'Full Time': 8709

# %% [markdown]
# ##preferred to drop working hours column

# %%
df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %% [markdown]
# #check working place.unique.count , remove "Posted" from colomn post_date , remove "be the first to apply" from number of applicants and make it 0
# #remove Nan from number of positions and put 0, check career_level, check education, prefered to drop salary but count 1st numb of confidential

# %%
print(df['Working_Place'].value_counts())
# Out:
# Working_Place
# On-site                        7805
# Hybrid                          580
# Remote                          520
# information technology (it)       9
# Information Technology (IT)       5
# Marketing                         5
# sales                             4
# Administration                    4
# kuwaitis                          4
# Maintenance                       4
# Sales                             3
# Human Resources (HR)              3
# Collection                        2
# saudi                             2
# Customer Service                  2
# Project Management                2
# Kitchen                           2
# Customer Support                  2
# marketing                         2
# Business Development              2
# Leasing                           1
# hospitality                       1
# QC                                1
# teachers                          1
# internship                        1
# ...

# %% [markdown]
# #replace other values in Working_Place and replace it with onsite

# %% [markdown]
# #post date (edit)

# %%
# Remove "Posted" from the 'post_date' column
df['Post_Date'] = df['Post_Date'].str.replace('Posted', '', regex=False)

df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %%
# Remove "be the first to apply" from 'Number_of_Applicants' and replace with 0
df['Number_of_Applicants'] = df['Number_of_Applicants'].replace('Be the First to Apply', '0')

df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8983 entries, 0 to 8982
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 8983 non-null   object
#  1   Working_Hours         8983 non-null   object
#  2   Working_Place         8983 non-null   object
#  3   Company               7949 non-null   object
#  4   Location              8983 non-null   object
#  5   Post_Date             8983 non-null   object
#  6   Number_of_Applicants  8982 non-null   object
#  7   Number_of_Positions   8668 non-null   object
#  8   Experience            8983 non-null   object
#  9   Career_Level          8983 non-null   object
#  10  Education             8983 non-null   object
#  11  Salary                8176 non-null   object
#  12  Job_Category          8983 non-null   object
#  13  Skills                8983 non-null   object
#  14  Gender                807 non-null    object
# ...

# %%
df['Number_of_Positions'] = df['Number_of_Positions'].fillna(1)
df['Number_of_Positions'] = df['Number_of_Positions'].astype(int)

df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8983 entries, 0 to 8982
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 8983 non-null   object
#  1   Working_Hours         8983 non-null   object
#  2   Working_Place         8983 non-null   object
#  3   Company               7949 non-null   object
#  4   Location              8983 non-null   object
#  5   Post_Date             8983 non-null   object
#  6   Number_of_Applicants  8982 non-null   object
#  7   Number_of_Positions   8983 non-null   int64
#  8   Experience            8983 non-null   object
#  9   Career_Level          8983 non-null   object
#  10  Education             8983 non-null   object
#  11  Salary                8176 non-null   object
#  12  Job_Category          8983 non-null   object
#  13  Skills                8983 non-null   object
#  14  Gender                807 non-null    object
# ...

# %%
print(df['Career_Level'].value_counts())
# Out:
# Career_Level
# Experienced (Non-Manager)                      5501
# Entry Level (Junior Level / Fresh Grad)        2098
# Manager                                        1100
# Senior Management (CEO, GM, Director, Head)     167
# Not Specified                                    78
# Student (Undergrad / Postgrad)                   39
# Name: count, dtype: int64

# %% [markdown]
# #take females and males preferred to gender

# %%
print(df['Salary'].value_counts())
# Out:
# Salary
# Confidential                                      5607
# Males Preferred                                    118
# Females Preferred                                   60
# Confidential, Bonus                                 52
# Confidential, Commission                            50
#                                                   ...
# Confidential, Attractive Package                     1
# 6000 To 6500 EGP Per Month                           1
# 5000 To 10000 USD Per Month                          1
# Confidential, Depend On Interview                    1
# 10000 To 30000 EGP Per Month, Bonus Commission       1
# Name: count, Length: 1296, dtype: int64

# %%
print(df['Education'].value_counts())
# Out:
# Education
# Bachelor'S Degree              5180
# Not Specified                  3725
# High School (Or Equivalent)      32
# Master'S Degree                  29
# Diploma                          11
# MBA                               4
# College Diploma                   2
# Name: count, dtype: int64

# %%
df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %% [markdown]
# # Drop duplicates

# %%
df = df.drop_duplicates()
df
# Out:
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# 8980          Senior Front End Developer (Vuejs)     Full Time
# 8981             Maintenance Mechanical Engineer     Full Time
# 8982              Executive Sales Representative     Full Time
#
#                     Working_Place  \
# 0                         On-site
# 1                          Hybrid
# 2                         On-site
# 3                         On-site
# ...

# %%
df["Gender"] = df["Gender"].fillna("both")
df
# Out:
# <ipython-input-54-96504da9ca49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gender"] = df["Gender"].fillna("both")
#                                            Title Working_Hours  \
# 0                      School Head of Admissions     Full Time
# 1                       Senior Backend Developer     Full Time
# 2                                 Civil Engineer     Full Time
# 3                      Senior Tendering Engineer     Full Time
# 4                       Senior Android Developer     Full Time
# ...                                          ...           ...
# 8978       Content & Digital Marketing Executive     Full Time
# 8979  Application Tester - 6 Months (Extendable)     Full Time
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8259 entries, 0 to 8982
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 8259 non-null   object
#  1   Working_Hours         8259 non-null   object
#  2   Working_Place         8259 non-null   object
#  3   Company               7314 non-null   object
#  4   Location              8259 non-null   object
#  5   Post_Date             8259 non-null   object
#  6   Number_of_Applicants  8258 non-null   object
#  7   Number_of_Positions   8259 non-null   int64
#  8   Experience            8259 non-null   object
#  9   Career_Level          8259 non-null   object
#  10  Education             8259 non-null   object
#  11  Salary                7514 non-null   object
#  12  Job_Category          8259 non-null   object
#  13  Skills                8259 non-null   object
#  14  Gender                8259 non-null   object
# ...

# %%
df["Number_of_Applicants"] = df["Number_of_Applicants"].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8259 entries, 0 to 8982
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 8259 non-null   object
#  1   Working_Hours         8259 non-null   object
#  2   Working_Place         8259 non-null   object
#  3   Company               7314 non-null   object
#  4   Location              8259 non-null   object
#  5   Post_Date             8259 non-null   object
#  6   Number_of_Applicants  8259 non-null   object
#  7   Number_of_Positions   8259 non-null   int64
#  8   Experience            8259 non-null   object
#  9   Career_Level          8259 non-null   object
#  10  Education             8259 non-null   object
#  11  Salary                7514 non-null   object
#  12  Job_Category          8259 non-null   object
#  13  Skills                8259 non-null   object
#  14  Gender                8259 non-null   object
# ...

# %% [markdown]
# #experience column separate it into 2 columns from and to

# %% [markdown]
# #skills column change from list to text
# #check for duplicated skills that have same meaning
# #sales and sales target fy "s" gya out of nowhere !!!!!!
